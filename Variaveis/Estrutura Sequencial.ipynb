# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Alo mundo")
# Out:
# Alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = input('Digite seu número: ')
print(f'O número informado foi {numero}.')
# Out:
# O número informado foi 15.0.

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
num1 = float(input('Digite o primeiro número: '))
num2 = float(input('Digite o segundo número: '))

print(f'A soma entre {num1} e {num2} é {num1 + num2}.')
# Out:
# A soma entre 10.0 e 10.0 é 20.0.

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
bim1 = float(input('Digite a nota do primeiro bimestre: '))
bim2 = float(input('Digite a nota do segundo bimestre: '))
bim3 = float(input('Digite a nota do terceiro bimestre: '))
bim4 = float(input('Digite a nota do quarto bimestre: '))

media = (bim1 + bim2 + bim3 + bim4) / 4

print(f'A média das notas é {media:.1f}.')
# Out:
# A média das notas é 8.5.

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metros = float(input('Digite o valor em metros: '))

cm = metros * 100

print(f'O valor em centímetros é {cm:.1f}.')
# Out:
# O valor em centímetros é 70.0.

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura_sala = float(input('Digite a largura da sua sala: '))
comprimento_sala = float(input('Digite a comprimento da sua sala: '))

area_sala = largura_sala * comprimento_sala

print(f'A área da sua sala é de {area_sala:.1f} m².')
# Out:
# A área da sua sala é de 600.0 m².

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
valor_hora = float(input('Digite quanto voce recebe por hora: '))
hrs_trabalhadas = float(input('Digite quanto voce trabalha no mês: '))

salario = valor_hora * hrs_trabalhadas

print(f'O seu salário é de R${salario:.2f}.')
# Out:
# O seu salário é de R$3024.00.

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
fahrenheit = float(input('Digite a temperatura em graus Fahrenheit: '))

celsius = 5 / 9 * (fahrenheit - 32)

print(f'A temperatura em graus Celsius é de {celsius:.1f}.')
# Out:
# A temperatura em graus Celsius é de 18.3.

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
celsius = float(input('Digite a temperatura em graus Celsius: '))

fahrenheit = 9 / 5 * celsius + 32

print(f'A temperatura em graus Fahrenheit é de {fahrenheit:.1f}.')
# Out:
# A temperatura em graus Fahrenheit é de 86.0.

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input('Digite a sua altura para saber seu peso ideal: '))

peso_ideal = 72.7 * altura - 58

print(f'O seu peso ideal é de {peso_ideal:.1f} kg.')
# Out:
# O seu peso ideal é de 65.6 kg.

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura = float(input('Digite sua altura: '))

peso_ideal_homem = 72.7 * altura - 58
peso_ideal_mulher = 62.1 * altura - 44.7

print(f'O peso ideal é de {peso_ideal_homem:.1f} kg para homens e {peso_ideal_mulher:.1f} kg para mulheres.')
# Out:
# O peso ideal é de 65.6 kg para homens e 60.9 kg para mulheres.

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
valor_hora = float(input('Digite o seu valor por hora: '))

hrs_trabalhadas = float(input('Digite o número de horas trabalhadas no mês: '))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = valor_hora * hrs_trabalhadas

print(f'O seu salário bruto é de R${salario_bruto:.2f}.')
# Out:
# O seu salário bruto é de R$2520.00.

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
desconto_ir = salario_bruto * 0.11

print(f'O desconto do IR é de R${desconto_ir:.2f}.')
# Out:
# O desconto do IR é de R$277.20.

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
desconto_inss = salario_descontado * 0.08

print(f'O desconto do INSS é de R${desconto_inss:.2f}.')
# Out:
# O desconto do INSS é de R$179.42.

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
desconto_sindicato = salario_descontado_inss * 0.05

print(f'O desconto do sindicato é de R${desconto_sindicato:.2f}.')
# Out:
# O desconto do sindicato é de R$103.17.

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_liquido = salario_bruto - (desconto_ir + desconto_inss + desconto_sindicato)

print(f'O seu salário líquido é de R${salario_liquido:.2f}.')
# Out:
# O seu salário líquido é de R$1960.21.

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area_pintada = float(input('Digite a área a ser pintada em metros quadrados: '))
lata_litros = area_pintada / 3
preco_lata = 80.0

latas = lata_litros / 18

preco_total = latas * preco_lata

print(f'Para pintar a área de {area_pintada:.1f}m², você vai precisar de {latas:.1f} latas de tinta, que custam R${preco_lata:.2f}cada e vai totalizar R${preco_total:.2f}.')
# Out:
# Para pintar a área de 25.0m², você vai precisar de 0.5 latas de tinta, que custam R$80.00cada e vai totalizar R$37.04.

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho_mb = float(input('Digite o tamanho do arquivo em megabyte: '))

velocidade_mbps = float(input('Digite a velocidade do seu link de Internet em megabits por segundo: '))

tempo_download = (8 * tamanho_mb / velocidade_mbps) / 60

print(f'O tempo de download do arquivo é de {tempo_download:.1f} minutos.')
# Out:
# O tempo de download do arquivo é de 13.3 minutos.
